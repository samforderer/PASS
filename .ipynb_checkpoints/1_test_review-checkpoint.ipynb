# %% [markdown]
# # PASS Session 4: Test 1 Review

# %% [markdown]
# ## Agenda
# 1. Disclaimer
# 2. Icebreaker
# 3. 5 Module review

# %% [markdown]
# **OPEN UP FOLLOWING SLIDES**
# - Review Lecture: Test 1

# %% [markdown]
# The test will be covering the 5 first modules:
#
# 1. **Problem Solving**
#
# 2. **Logic**
#
# 3. **Modelling Solutions**
#
# 4. **Programming Concepts**
#
# 5. **Intro to Python**

# %% [markdown]
# *For each unit in this document there is a description of what the test questions will be like for that unit. I have created questions that will help us prepare for the test expectations as noted in your professor's slides.*

# %% [markdown]
# ---

# %% [markdown]
# # 1. Problem Solving

# %% [markdown]
# 1. Multiple choice, True/False.
# 2. Briefly explain x problem solving technique and its importance in software development.
# 3. Riddle:

# %% [markdown]
# **Identify the 5 Problem solving techniques, their definitions and why they are important in software developnment**

# %% [markdown]
# Decomposition
# - breaking the problem down into smaller chunks

# %% [markdown]
# Abstraction
# - Making a complex problem into a simpler version

# %% [markdown]
# Analogy
# - finding a similar version of the problem that we already know how to solve

# %% [markdown]
# Trial and Error
# - try it, if it doesn't work, try something else. Learning from mistakes

# %% [markdown]
# Lateral thinking
# - thinking outside of the box

# %% [markdown]
# ---

# %% [markdown]
# # 2. Logic

# %% [markdown]
# 1. Multiple choice, True/False.
# 2. No questions to solve grid puzzle

# %% [markdown]
# **Match the definitions to the problem solving strategy**

# %% [markdown]
# 1. Your best guess with the information you have right now.
#
# 2. Someone makes a disgusted face after taking a bite of their sandwich. They most likely do not like the sandwich.
#
# 3. A 100% true conclusion drawn from axioms and implications
# - Deduction
#
# 4. A general conclusion given a collection of specific facts. Evolving with information stream.
# - inference
#
# 5. An IF/THEN relationship.
# - Implication

# %% [markdown]
# **Is the following a valid deduction?** (T/F)
#
# - All dogs have four legs
#
# - All dogs are animals
#
# - Therefore, all animals have four legs

# %% [markdown]
# ---

# %% [markdown]
# # 3. Modelling Solutions

# %% [markdown]
# 1. Multiple choice, True/False about Pseudocode, IPO charts, Flow Charts.
# 2. Q/A: e.g., create an IPO chart for a problem; Trace variables in a flow chart; Write Pseudocode from an IPO chart etc.

# %% [markdown]
# **General questions about models**
#
# 1. Which model is used in the *Define* stage of DDIT
#
# 2. Do we use pseudocode inside IPO?
#
# 3. Each line of pseudocode should be started with a _______
#
# 4. Each line of pseudocode presents how many actions?
#
# 5. Are you allowed to use mathematical operators in pseudocode?
#
# 6. Which model is used in the *Design* stage of DDIT?
#
# 7. Do we test models?

# %% [markdown]
# **Create IPO Chart for a problem**
#
# - Burnaby Farms wants to estimate the cost of fertilizing their fields for the coming year
# - They want to enter the cost of fertilizer per hectar and the number of hectares
# - They want the program to tell them the total cost of fertilizer
# - Their budget is $15,000; they also want the program to report if they are over or under budget

# %% [markdown]
# INPUT:

# %% [markdown]
# PROCESSING:

# %% [markdown]
# OUTPUT:

# %% [markdown]
# **Convert this IPO to pseudocode**

# %% [markdown]
# **Trace Flowchart**

# %% [markdown]
# ![image.png](attachment:ee083ff6-87f1-4b4f-9eb9-1b78579c1138.png)

# %% [markdown]
# ![image.png](attachment:8b05ddf1-c0c9-4af3-b02d-b2594e58e152.png)

# %% [markdown]
# ---

# %% [markdown]
# # 4. Programming Concepts

# %% [markdown]
# 1. Multiple choice, True/False about Algorithms, memory and variables, Data types.
# 2. Q/A: Explain about DDIT briefly;

# %% [markdown]
# ## DDIT
# *Fill in the terms and definitions*
# 1.
#
# 2.
#
# 3.
#
# 4.
#
# 5.

# %% [markdown]
# ## Data Types
# **Identify the 4 data types**

# %% [markdown]
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# **Define Algorithm**

# %% [markdown]
# > a process or set of rules to be followed for solving a problem or performing a computation
# - abdul

# %% [markdown]
# **Explain how variables relate to memory**

# %% [markdown]
# when we declare a variable, we allocate space in memory,it is stored at a memory address

# %% [markdown]
# ---

# %% [markdown]
# # 5. Intro to Python

# %% [markdown]
# ## Precedence

# %% [markdown]
# 1. Brackets
# 2. Exponents
# 3. Division/Multiplication [These have the same precedence]
# 4. Addition/Subtraction

# %% [markdown]
# ## Statement vs Expression
# *Fill in the terms and definitions*

# %% [markdown]
# Statement:

# %% [markdown]
# Expression:

# %% [markdown]
# 1. Multiple choice, True/False about
# - variables, expressions, and statements in python;
# - input and output in python,
# - data type and conversions in python (e.g., x = int( float( "1.01" ) ?)
#
# e.g., What is the final data type of x after running the following code:
#
# x = 3.0
#
# x = 3
#
# x = "3"
#
# ◦ Math in python e.g., x = round(1.1500001, 1)? x=9.0%-2?

# %% [markdown]
# 2. Write Math equation using arithmetic operators in Python

# %% [markdown]
# 3. Python I/O Code Writing using input and prin

# %% [markdown]
# ---

# %%
# Out:
# 10
